# %% [markdown]
# # Advanced Semantic Kernel - Advanced Agent Features
#
# Welcome to the advanced agent features tutorial! This notebook builds on the basics to explore sophisticated individual agent capabilities and enhancements.
#
# ## Prerequisites
#
# Before starting this tutorial, make sure you've completed the **Semantic Kernel Basics** notebook. You should be familiar with:
# - Basic agent creation and configuration
# - Chat completion services
# - Plugins and function calling
# - Conversation threads
#
# ## What You'll Learn
#
# - **Streaming Responses**: Real-time response generation with `invoke_stream()`
# - **Intermediate Steps**: Understanding agent processing with `invoke()`
# - **Structured Outputs**: Enforcing consistent response formats with Pydantic
# - **Reasoning Models**: Enhanced reasoning capabilities with specialized models
#
# ## Resources
# - [Agent API Reference](https://learn.microsoft.com/en-us/semantic-kernel/frameworks/agent/agent-api?pivots=programming-language-python)
# - [Reasoning Models](https://learn.microsoft.com/en-us/azure/ai-foundry/openai/how-to/reasoning?tabs=python-secure%2Cpy)
#
# ## Next Steps
# After completing this tutorial, continue with the **Semantic Kernel Multi-Agent Orchestration** notebook to learn about agent collaboration patterns.
#
# Let's explore these advanced agent features!

# %% [markdown]
# ## Setup and Imports
#
# Let's start by importing the necessary modules for advanced agent features.

# %%
import asyncio
import json
import os
from dotenv import load_dotenv
from pydantic import BaseModel

try:
    from typing import Annotated
except ImportError:
    from typing_extensions import Annotated

# Core Semantic Kernel imports
from semantic_kernel import Kernel
from semantic_kernel.agents import Agent, ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion, OpenAIChatCompletion
from semantic_kernel.connectors.ai.open_ai import OpenAIChatPromptExecutionSettings, AzureChatPromptExecutionSettings
from semantic_kernel.functions import kernel_function, KernelArguments
from semantic_kernel.contents import ChatMessageContent, TextContent, StreamingChatMessageContent
from semantic_kernel.contents.utils.author_role import AuthorRole
from semantic_kernel.contents.chat_history import ChatHistory
from semantic_kernel.contents import FunctionCallContent, FunctionResultContent

# Load environment variables
load_dotenv()

print("✅ Advanced agent imports loaded successfully!")
# Out:
# ✅ Advanced agent imports loaded successfully!

# %%
# Configure the main chat completion service
chat_completion = AzureChatCompletion(
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    deployment_name=os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME"),
)

print("✅ Chat completion services configured!")
# Out:
# ✅ Chat completion services configured!

# %% [markdown]
# ## 1. Advanced Agent Features
#
# Let's explore advanced agent capabilities including streaming responses and intermediate step handling.

# %% [markdown]
# ### 1.1 Streaming Responses
#
# Streaming allows you to see responses as they're generated, providing a better user experience for long responses.

# %%
# Create a simple agent for streaming demonstration
streaming_agent = ChatCompletionAgent(
    service=chat_completion,
    name="StreamingExpert",
    instructions="You are an expert who provides detailed explanations. Give comprehensive responses about topics.",
)

# %%
# Example 1: Regular (non-streaming) response
print("📝 Regular Response:")
print("=" * 40)
response = await streaming_agent.get_response(
    messages="Explain the benefits of renewable energy in detail."
)
print(response.message.content)

print("\n" + "=" * 40)
# Out:
# 📝 Regular Response:
# ========================================
# Renewable energy refers to power generated from resources that are naturally replenished, such as sunlight (solar), wind, water (hydropower), geothermal heat, and biomass. Switching to renewable energy sources offers numerous significant benefits across environmental, economic, social, and technological domains. Here’s a detailed explanation:
#
# **1. Environmental Benefits**
#
# - **Reduced Greenhouse Gas Emissions:** Unlike fossil fuels (coal, oil, natural gas), renewables emit little or no greenhouse gases during energy production. This helps combat climate change by lowering the concentration of carbon dioxide and other harmful gases in the atmosphere.
# - **Lower Air and Water Pollution:** Renewable sources produce minimal air pollutants (such as sulfur dioxide, nitrogen oxides, and particulates) and are less likely to contaminate water supplies, benefiting public health and local ecosystems.
# - **Mitigating Climate Change:** By reducing reliance on fossil fuels, renewables diminish the principal cause of anthropogenic climate change, helping stabilize weather patterns and minimize extreme events.
#
# **2. Economic Benefits**
#
# - **Job Creation:** The renewable energy sector is labor-intensive and has generated millions of jobs globally in manufacturing, installation, maintenance, research, and development.
# - **Energy Price Stability:** Renewable technologies, like wind and solar, have low operating costs after installation and are not subject to volatile global fuel prices, providing more predictable pricing for consumers and businesses.
# - **Diversification of Energy Supply:** Renewables make energy portfolios more resilient to disruption and reduce dependence on imports, improving national energy security.
#
# **3. Social Benefits**
#
# - **Energy Access and Equity:** Renewables like solar panels and small-scale wind turbines can be deployed in remote and underserved communities, increasing access to electricity and improving quality of life.
# - **Improved Health Outcomes:** By reducing pollution, renewables help decrease respiratory and cardiovascular illnesses associated with fossil fuel combustion.
# - **Community Empowerment:** Local ownership models, such as community wind farms or solar co-ops, promote social inclusion and allow people to control their energy sources.
#
# **4. Technological and Infrastructural Benefits**
#
# - **Innovation and Advancement:** Investing in renewable energy drives technological development, leading to more efficient systems, energy storage solutions, smart grids, and new business models.
# - **Reduced Transmission Losses:** Distributed renewable systems (like rooftop solar) enable electricity generation closer to where it’s used, minimizing losses that typically occur during long-distance transmission.
#
# **5. Sustainability**
#
# - **Resource Depletion Minimization:** Renewables rely on abundant resources (sun, wind, water), unlike finite fossil fuels. Their use does not diminish the supply for future generations.
# - **Land and Habitat Protection:** Properly managed renewables can coexist with agriculture and other land uses with less environmental disturbance compared to large-scale mining and drilling sites.
#
# **6. Long-term Cost Savings**
#
# - **Lower Operating Costs:** Once installed, renewables have lower maintenance and operational costs compared to fossil fuel plants, which require ongoing fuel purchases, handling, and waste management.
# - **External Cost Reduction:** By avoiding pollution and greenhouse gas emissions, renewables help reduce public expenditures associated with healthcare and environmental remediation.
#
# **Conclusion**
#
# The transition to renewable energy offers a holistic package of benefits, from protecting the environment and improving public health to creating economic opportunities and enhancing energy security. As technology advances and costs decline, the adoption of renewables becomes increasingly advantageous for individuals, communities, and nations around the world.
#
# ========================================

# %%
# Example 2: Streaming response using invoke_stream()
print("🌊 Streaming Response:")
print("=" * 40)
async for streaming_response in streaming_agent.invoke_stream(
    messages="Explain the challenges of implementing AI in healthcare."
):
    # This shows the response as it's being generated in real-time
    print(streaming_response.content, end="", flush=True)

print("\n\n✅ Streaming examples completed!")
# Out:
# 🌊 Streaming Response:
# ========================================
# Implementing AI in healthcare presents a range of significant challenges that stem from technical, ethical, regulatory, and practical considerations. Here’s a comprehensive overview:
#
# **1. Data Quality and Availability:**
#    - *Fragmentation and Silos:* Healthcare data is often stored in disparate electronic health record (EHR) systems and formats, leading to fragmented information.
#    - *Data Quality:* Clinical notes may be unstructured; records can contain errors, omissions, or inconsistencies.
#    - *Lack of Standardization:* Medical terminology, imaging formats, and coding can vary, complicating integration and analysis.
#
# **2. Privacy, Security, and Compliance:**
#    - *Sensitive Data:* Patient health information (PHI) is highly sensitive and protected by regulations such as HIPAA (US) and GDPR (Europe).
#    - *Cybersecurity Risks:* As more systems become connected, they are vulnerable to breaches or ransomware attacks.
#    - *Consent and Data Sharing:* Obtaining explicit patient consent for data usage and sharing across institutions can be difficult.
#
# **3. Bias and Fairness:**
#    - *Representativeness:* AI models may be trained on data that under-represent certain populations, leading to biased predictions.
#    - *Health Disparities:* If not addressed, AI may exacerbate existing health inequities by providing less accurate recommendations for marginalized groups.
#    - *Algorithmic Transparency:* It’s often hard to understand how decisions are reached, risking “black box” outcomes with biased results.
#
# **4. Integration with Existing Workflows:**
#    - *Clinician Adoption:* Healthcare professionals may be hesitant to trust or adopt AI tools, especially if they disrupt routine processes.
#    - *Workflow Compatibility:* Integrating AI tools smoothly into existing clinical workflows and EHR systems is complex and time-consuming.
#    - *Training and Change Management:* Staff need training to use new tools effectively and safely.
#
# **5. Regulatory and Validation Issues:**
#    - *Regulatory Approval:* AI-based devices and diagnostics must meet stringent regulatory standards (FDA, EMA), but regulatory pathways are still evolving.
#    - *Clinical Validation:* AI models require exhaustive validation and testing in real-world clinical settings to confirm accuracy and safety.
#    - *Continuous Monitoring:* AI models may degrade over time as clinical practices and populations change, needing ongoing oversight.
#
# **6. Ethical and Legal Challenges:**
#    - *Accountability:* If AI makes a clinical error, determining liability is complex—does it lie with the developer, provider, or institution?
#    - *Informed Consent:* Patients must be adequately informed about AI’s role in their care to give meaningful consent.
#    - *Transparency and Explainability:* Ensuring that AI decisions can be explained to patients and clinicians is critical for trust.
#
# **7. Technical Limitations:**
#    - *Generalizability:* AI algorithms trained on data from specific sources may not generalize well to other settings or populations.
#    - *Interpretability:* Many AI models, especially deep learning networks, are difficult to interpret, posing challenges for clinical adoption.
#    - *Scalability:* Deploying AI solutions at scale requires robust infrastructure and significant investment.
#
# **8. Cost and Resource Constraints:**
#    - *Initial Investment:* Developing, deploying, and maintaining AI systems can be expensive.
#    - *Resource Allocation:* Continuous data labeling, annotation, and system updates demand significant resources.
#
# **In Summary:**
# Deploying AI in healthcare requires overcoming technical hurdles (data quality, interoperability, reliability), addressing privacy and ethical concerns, navigating regulatory landscapes, ensuring equitable and bias-free outcomes, and securing clinician and patient trust. Successful implementation demands cross-disciplinary collaboration between technologists, healthcare professionals, regulators, and patients.
#
# ✅ Streaming examples completed!

# %% [markdown]
# ### 1.2 Intermediate Steps with invoke()
#
# **Understanding Agent Methods:**
#
# - **`get_response()`**: Provides the final response only - blocks until the agent is completely done processing
# - **`invoke()`**: Allows you to see the agent's step-by-step thinking process, including intermediate function calls and results
# - **`invoke_stream()`**: Provides real-time streaming of the response as it's being generated
#
# The `invoke()` method is particularly useful when you want to understand how the agent is working with plugins and function calls.

# %%
class AnalysisPlugin:
    """Plugin that provides analysis capabilities."""
    
    @kernel_function(description="Analyze a topic and provide insights.")
    def analyze_topic(self, topic: Annotated[str, "The topic to analyze"]) -> str:
        # Simulate analysis processing
        return f"Analysis of '{topic}': This is a complex topic that requires careful consideration of multiple factors including market trends, user needs, and technical feasibility."
    
    @kernel_function(description="Generate recommendations based on analysis.")
    def generate_recommendations(self, analysis: Annotated[str, "The analysis to base recommendations on"]) -> str:
        return "Recommendations: 1) Conduct further research, 2) Develop a prototype, 3) Test with users, 4) Iterate based on feedback."

# Create an agent with the analysis plugin for the next section
analysis_agent = ChatCompletionAgent(
    service=chat_completion,
    name="AnalysisExpert",
    instructions="You are an expert analyst. Use your tools to provide thorough analysis and recommendations.",
    plugins=[AnalysisPlugin()]
)

# %%
async def handle_intermediate_steps(message: ChatMessageContent) -> None:
    """Handle intermediate steps in the agent's processing."""
    for item in message.items or []:
        if isinstance(item, FunctionResultContent):
            print(f"🔧 Function Result: {item.result}")
        elif isinstance(item, FunctionCallContent):
            print(f"📞 Function Call: {item.name} with arguments: {item.arguments}")
        else:
            print(f"💭 {message.name}: {message.content}")

# Test intermediate steps
task = "Analyze the potential of AI-powered educational tools and provide recommendations."
print(f"🎯 Task: {task}")
print("=" * 60)

async for response in analysis_agent.invoke(
    messages=task,
    on_intermediate_message=handle_intermediate_steps
):
    print(f"✅ Final Response from {response.name}: {response.content}")
# Out:
# 🎯 Task: Analyze the potential of AI-powered educational tools and provide recommendations.
# ============================================================
# 📞 Function Call: AnalysisPlugin-analyze_topic with arguments: {"topic":"Potential of AI-powered educational tools"}
# 🔧 Function Result: Analysis of 'Potential of AI-powered educational tools': This is a complex topic that requires careful consideration of multiple factors including market trends, user needs, and technical feasibility.
# 📞 Function Call: AnalysisPlugin-analyze_topic with arguments: {"topic":"Potential of AI-powered educational tools"}
# 🔧 Function Result: Analysis of 'Potential of AI-powered educational tools': This is a complex topic that requires careful consideration of multiple factors including market trends, user needs, and technical feasibility.
# ✅ Final Response from AnalysisExpert: AI-powered educational tools have significant potential to revolutionize learning by offering personalized instruction, automating administrative tasks, and supporting differentiated education. Some key factors influencing their potential include:
#
# - Market trends are showing increased adoption of digital tools in education, spurred by remote learning needs and technological advancements.
# - User needs vary among students, educators, and institutions, but AI can adapt to individual learning paces and styles, providing real-time feedback and adaptive testing.
# - Technical feasibility is high, with advances in natural language processing and machine learning, enabling smarter tutoring systems, automated grading, and language learning assistance.
#
# Would you like detailed recommendations on implementing or adopting AI-powered educational tools?

# %%
# Straming with intermediate steps
async for streaming_response in analysis_agent.invoke_stream(
    messages=task,
    on_intermediate_message=handle_intermediate_steps
):
    print(streaming_response.content, end="", flush=True)
# Out:
# 📞 Function Call: AnalysisPlugin-analyze_topic with arguments: {"topic":"AI-powered educational tools"}
# 🔧 Function Result: Analysis of 'AI-powered educational tools': This is a complex topic that requires careful consideration of multiple factors including market trends, user needs, and technical feasibility.
# 📞 Function Call: AnalysisPlugin-generate_recommendations with arguments: {"analysis":"AI-powered educational tools demonstrate significant potential to transform learning experiences in both formal and informal settings. These tools leverage artificial intelligence to provide personalized learning paths, automate grading, track student performance, offer adaptive testing, deliver immediate feedback, and create immersive environments (e.g., via virtual tutors or AI chatbots). AI can also support differentiated instruction for students with varied learning styles or special needs, scale education to underserved regions, and automate administrative tasks. However, issues like data privacy, algorithmic bias, teacher adoption, and infrastructure limitations must be addressed for broad implementation. With increasing investments and advancements in AI, the educational sector is poised for rapid innovation, but must navigate ethical and practical challenges to ensure equitable access and impact."}
# 🔧 Function Result: Recommendations: 1) Conduct further research, 2) Develop a prototype, 3) Test with users, 4) Iterate based on feedback.
# Analysis:
# AI-powered educational tools have immense potential to revolutionize how education is delivered and experienced. Their key advantages include:
#
# - Personalized learning experiences, tailored content, and adaptive testing.
# - Automated grading, performance tracking, and immediate feedback to both students and educators.
# - Enhanced support for diverse learning styles and special needs.
# - Scalable solutions for remote or underserved populations.
# - Efficiency improvements in administrative and teaching processes.
#
# However, successful adoption faces challenges such as data privacy concerns, potential biases in AI algorithms, teacher training, user trust, and varying levels of technological infrastructure.
#
# Recommendations:
#
# 1. Conduct Further Research: Investigate specific educational contexts where AI tools address meaningful challenges and ensure technology choices align with user needs.
# 2. Develop a Prototype: Build a minimum viable AI-powered educational tool focusing on high-impact areas such as personalized feedback or adaptive quizzes.
# 3. Test with Users: Engage real students, educators, and administrators in pilot testing to collect genuine user experiences and data.
# 4. Iterate Based on Feedback: Use collected insights to refine the tool, addressing usability, effectiveness, accessibility, and ethical considerations.
# 5. Emphasize Equity and Privacy: Ensure solutions are designed to minimize bias, protect user data, and offer equitable access across socioeconomic strata.
#
# Would you like a deeper dive into specific AI educational technologies, implementation strategies, or success case studies?

# %% [markdown]
# ### 1.3 Structured Outputs with Pydantic
#
# You can enforce structured responses using Pydantic models, ensuring consistent output format.

# %%
# Define structured output models
class Step(BaseModel):
    explanation: str
    output: str

class MathSolution(BaseModel):
    steps: list[Step]
    final_answer: str

# Create an agent with structured output
settings = AzureChatPromptExecutionSettings()
settings.response_format = MathSolution

math_agent = ChatCompletionAgent(
    service=chat_completion,
    name="MathTutor",
    instructions="You are a math tutor. Solve problems step by step and provide clear explanations.",
    arguments=KernelArguments(settings=settings)
)

# Test structured output
problem = "Solve: 3x + 7 = 22"
print(f"🧮 Problem: {problem}")

response = await math_agent.get_response(messages=problem)
solution = MathSolution.model_validate(json.loads(response.message.content))

print("\n📚 Structured Solution:")
print(solution.model_dump_json(indent=2))
# Out:
# 🧮 Problem: Solve: 3x + 7 = 22
#
# 📚 Structured Solution:
# {
#   "steps": [
#     {
#       "explanation": "Start with the given equation: 3x + 7 = 22. The goal is to solve for x. First, subtract 7 from both sides to isolate the term with x.",
#       "output": "3x + 7 - 7 = 22 - 7"
#     },
#     {
#       "explanation": "Simplify both sides. On the left, 7 - 7 is 0, so we're left with 3x. On the right, 22 - 7 is 15.",
#       "output": "3x = 15"
#     },
#     {
#       "explanation": "Now, divide both sides by 3 to solve for x.",
#       "output": "x = 15 / 3"
#     },
#     {
#       "explanation": "Divide 15 by 3 to get the value of x.",
#       "output": "x = 5"
#     }
#   ],
#   "final_answer": "x = 5"
# }

# %% [markdown]
# ### 1.4 Reasoning Models (if available)
#
# Some models like O1 provide enhanced reasoning capabilities. Let's test if we have access to reasoning models.

# %%
# Configure reasoning model (if available)
reasoning_completion = None
if os.getenv("AZURE_REASONING_ENDPOINT"):
    reasoning_completion = AzureChatCompletion(
        api_key=os.getenv("AZURE_REASONING_API_KEY"),
        endpoint=os.getenv("AZURE_REASONING_ENDPOINT"),
        deployment_name=os.getenv("AZURE_REASONING_DEPLOYMENT_NAME"),
        # Reasoning models from OpenAI use "developer" role instead of "system"
        instruction_role="developer",
        service_id="reasoning"
    )
    
    reasoning_settings = AzureChatPromptExecutionSettings(
        service_id="reasoning",
        reasoning_effort="high" # low | medium | high
    )
    
    reasoning_agent = ChatCompletionAgent(
        name="ReasoningExpert",
        instructions="You are an expert problem solver. Think through complex problems step by step.",
        service=reasoning_completion,
    )
    
    print("✅ Reasoning model available!")
# Out:
# ✅ Reasoning model available!

# %%
if reasoning_completion:
    print("🧠 Testing reasoning model...")
    
    thread = ChatHistoryAgentThread()
    response = await reasoning_agent.get_response(
        messages="Solve: 2x + 3y = 7, 4x - y = 1. Show your reasoning.", 
        thread=thread
    )
    
    print(f"🧠 Reasoning Response: {response.message.content}")

    # Add another user message to the thread
    print("\n🤔 User: Is the solution correct? Explain.")
    response = await reasoning_agent.get_response(
        messages="Is the solution correct? Explain.", 
        thread=thread
    )
    print(f"🧠 Reasoning Response: {response.message.content}")
else:
    print("⚠️ Reasoning model not configured. Skipping reasoning example.")
    print("💡 To enable reasoning, configure AZURE_REASONING_* environment variables.")
# Out:
# 🧠 Testing reasoning model...
# 🧠 Reasoning Response: Here’s one way to solve the system step by step:
#
# 1. Write down the two equations:
#    Eq.(1): 2x + 3y = 7
#    Eq.(2): 4x – y  = 1
#
# 2. Choose a variable to eliminate.  We’ll eliminate y by making its coefficients opposites.
#    - Multiply Eq.(2) by 3:
#      3×(4x – y = 1)  →  12x – 3y = 3
#
# 3. Add this new equation to Eq.(1) so that +3y and –3y cancel:
#    (2x + 3y) + (12x – 3y) = 7 + 3
#    → 14x = 10
#    → x = 10/14 = 5/7
#
# 4. Substitute x = 5/7 back into one of the original equations to find y.  We’ll use Eq.(2):
#    4x – y = 1
#    4·(5/7) – y = 1
#    20/7 – y = 1
#    –y = 1 – 20/7 = (7/7 – 20/7) = –13/7
#    y = 13/7
#
# 5. Conclusion:
#    x = 5/7,  y = 13/7.
#
# 🤔 User: Is the solution correct? Explain.
# 🧠 Reasoning Response: Yes. You can verify it by plugging x=5/7, y=13/7 back into both equations:
#
# 1. Check 2x + 3y = 7
#    2·(5/7) + 3·(13/7) = 10/7 + 39/7 = 49/7 = 7 ✅
#
# 2. Check 4x – y = 1
#    4·(5/7) – (13/7) = 20/7 – 13/7 = 7/7 = 1 ✅
#
# Since both equations hold, the solution x=5/7, y=13/7 is correct.

# %%
# You can see the reasoning tokens used by the agent
async for message in thread.get_messages():
    print(f"📝 Message from {message.role}: {message.content[:20]}...")
    if message.metadata.get("usage", None):
        print(f"    🔍 Usage: {message.metadata['usage'].model_dump()}")
# Out:
# 📝 Message from AuthorRole.USER: Solve: 2x + 3y = 7, ...
# 📝 Message from AuthorRole.ASSISTANT: Here’s one way to so...
#     🔍 Usage: {'prompt_tokens': 55, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'completion_tokens': 708, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}}
# 📝 Message from AuthorRole.USER: Is the solution corr...
# 📝 Message from AuthorRole.ASSISTANT: Yes. You can verify ...
#     🔍 Usage: {'prompt_tokens': 381, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'completion_tokens': 291, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}}

# %%
await thread.delete()

# %% [markdown]
# ## 🎉 Congratulations!
#
# You've successfully completed the Advanced Agent Features tutorial! Here's what you've mastered:
#
# ### ✅ Advanced Agent Capabilities:
# 1. **Streaming Responses** - Real-time response generation with `invoke_stream()`
# 2. **Intermediate Steps** - Understanding agent processing with `invoke()` and callbacks
# 3. **Structured Outputs** - Enforcing consistent response formats with Pydantic models
# 4. **Reasoning Models** - Enhanced reasoning capabilities with specialized models and token tracking
#
# ### 🔧 Key Agent Methods:
# - **`get_response()`** - Blocking call that returns the final response
# - **`invoke()`** - Non-blocking call that shows intermediate steps and function calls
# - **`invoke_stream()`** - Real-time streaming of responses as they're generated
#
# ### 🚀 What's Next?
# Now that you've mastered individual agent capabilities, you're ready to explore multi-agent systems! Continue with the **Semantic Kernel Multi-Agent Orchestration** notebook to learn about:
# - Group chat orchestration patterns
# - Concurrent and sequential processing
# - Handoff systems
# - Human-in-the-loop workflows
#
# ### 📚 Additional Resources:
# - [Agent API Reference](https://learn.microsoft.com/en-us/semantic-kernel/frameworks/agent/agent-api?pivots=programming-language-python)
# - [Reasoning Models Documentation](https://learn.microsoft.com/en-us/azure/ai-foundry/openai/how-to/reasoning?tabs=python-secure%2Cpy)
# - [Plugin Development](https://learn.microsoft.com/en-us/semantic-kernel/concepts/plugins/)
#
# Great work! You're now ready to build sophisticated AI agents with advanced capabilities. 🚀
